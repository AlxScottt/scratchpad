# %% [markdown]
# <a href="https://colab.research.google.com/github/AlxScottt/scratchpad/blob/main/1_22_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/AlxScottt/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 40 (delta 8), reused 5 (delta 5), pack-reused 29 (from 1)
# Receiving objects: 100% (40/40), 44.44 KiB | 3.42 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/content/data/airbnb_NYC.csv", encoding="latin-1")
df.head()
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
#df['Neighbourhood '].value_counts().head(5).plot.bar(title='Top 5 Neighbourhood')
df['Neighbourhood '].value_counts().head(5).plot.pie(autopct='%1.1f%%', startangle=90, shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
df['Price'].value_counts().head(10).plot.bar(title='Top 10 Prices')
# Out:
# <Axes: title={'center': 'Top 10 Prices'}, xlabel='Price'>

# %%
df['Property Type'].value_counts().head(5).plot.pie(autopct='%1.1f%%', startangle=90, shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
df.loc[df['Review Scores Rating'] == '80' ]
# Out:
# Empty DataFrame
# Columns: [Host Id, Host Since, Name, Neighbourhood , Property Type, Review Scores Rating (bin), Room Type, Zipcode, Beds, Number of Records, Number Of Reviews, Price, Review Scores Rating]
# Index: []

# %%
import seaborn as sns

df2 = pd.read_csv("/content/data/sharks.csv")
df_small = df2.sample(300, random_state=42)
sns.pairplot(df_small)
# Out:
# /tmp/ipython-input-602467570.py:3: DtypeWarning: Columns (10,17,18,19,20,21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("/content/data/sharks.csv")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-602467570.py in <cell line: 0>()
#       3 df2 = pd.read_csv("/content/data/sharks.csv")
#       4 df_small = df2.sample(300, random_state=42)
# ----> 5 sns.pairplot(df_small)
#
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117     # Set up the PairGrid
#    2118     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
# ...

# %%
plt.show()
